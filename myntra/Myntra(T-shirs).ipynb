# %%
#start_index=1
#stop_index=201

# %%
import datetime
import time
import pymongo
import re
import requests as rt
import bs4
import json
import numpy as np
import sqlite3 as sq

# %%
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

# %%
def value_tester(index):
    print(product_links[index])
    print(mrp[index])
    print(price[index])
    print(description[index])
    print(gender[index])
    print(brand_names[index])
    print(product_names[index])
    print(primary_image_links[index])
    print(secondary_image_links[index])
    print(sizes[index])

# %% [markdown]
# # Men All Clothing

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/clothing?f=Gender%3Amen%2Cmen%20women&p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)
# Out:
# Total pages-  4118
# Total items- 205932

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/clothing?f=Gender%3Amen%2Cmen%20women&p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)
# Out:
# Exception Occured 'products'
# (89368, 89368, 89368, 89368, 89368, 89368, 89368, 89368, 89368, 89368)

# %%
b-a
# Out:
# datetime.timedelta(seconds=5378, microseconds=450075)

# %%
value_tester(89367)
# Out:
# https://www.myntra.com/Tshirts/Flying-Machine/Flying-Machine-Men-Black-Printed-T-Shirt/106948/buy
# 699
# 489
# Tshirts
# Men
# Flying Machine
# Flying Machine Men Black Printed T-Shirt
# http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_677f583f7aa2e5de901b195b8f522500_images.jpg
# ['http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_677f583f7aa2e5de901b195b8f522500_images.jpg', 'http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_5436c3912b934aa1dfee29c0277c9618_images.jpg', 'http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_ba1e7f339ed3245e86f97aac3c9e8283_images.jpg', 'http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_795f88fb34e4591be5568a577c7cd67b_images.jpg', 'http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_677f583f7aa2e5de901b195b8f522500_images.jpg', 'http://assets.myntassets.com/v1/images/style/properties/Flying-Machine-Men-Tshirts_de32c32d8c995a545595796787ac8147_images.jpg', '']
# ['M']

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Footwear

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-footwear?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-footwear?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(30000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Sunglasses/Frames

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-sunglasses?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-sunglasses?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(1000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Watches

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/mens-watches?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/mens-watches?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(2000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men SportsWear

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-sports-wear?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-sports-wear?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(10000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Wallet

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-wallets?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-wallets?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(2000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Belts

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-belts?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-belts?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(4000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Ties/Cufflinks/Pocket Squares

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-belts-ties?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-belts-ties?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(1000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Mufflers,Scarves & Gloves

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-gloves-mufflers-scarves?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-gloves-mufflers-scarves?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(300)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Rings Wristwear

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-jewellery?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-jewellery?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(500)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Men Bags Backpacks

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/men-bags-backpacks?f=Categories%3ABackpacks%2CHandbags%2CLaptop%20Bag%2CMessenger%20Bag&p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)
# Out:
# Total pages-  107
# Total items- 5395

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/men-bags-backpacks?f=Categories%3ABackpacks%2CHandbags%2CLaptop%20Bag%2CMessenger%20Bag&p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)
# Out:
# Exception Occured 'products'
# (5298, 5298, 5298, 5298, 5298, 5298, 5298, 5298, 5298, 5298)

# %%
value_tester(4000)
# Out:
# https://www.myntra.com/Backpacks/Impulse/Impulse-Unisex-Black-Solid-Backpack/11124310/buy
# 2199
# 989
# Unisex Solid Backpack
# Unisex
# Impulse
# Impulse Unisex Black Solid Backpack
# http://assets.myntassets.com/assets/images/productimage/2019/12/6/dd89f350-0412-4907-99b8-2a41ace1d6d91575590438642-1.jpg
# ['http://assets.myntassets.com/assets/images/productimage/2019/12/6/dd89f350-0412-4907-99b8-2a41ace1d6d91575590438642-1.jpg', 'http://assets.myntassets.com/assets/images/productimage/2019/12/6/dd89f350-0412-4907-99b8-2a41ace1d6d91575590438642-1.jpg', 'http://assets.myntassets.com/assets/images/productimage/2019/12/6/d6177a65-d66a-4003-b109-6be1c67be3421575590438817-5.jpg', '', 'http://assets.myntassets.com/assets/images/productimage/2019/12/6/a1ae1f53-073e-4004-b5aa-e800982f22801575590438731-3.jpg', 'http://assets.myntassets.com/assets/images/productimage/2019/12/6/f1bb2e5b-1c31-4078-8fc9-7455b18de0181575590438686-2.jpg', 'http://assets.myntassets.com/assets/images/productimage/2019/12/6/5051c68e-6356-4072-9051-8d52eec5885d1575590438775-4.jpg']
# ['Onesize']

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Phone Cases

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/mobile-phone-cases?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/mobile-phone-cases?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)

# %%
value_tester(10000)

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Women All Clothing

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/clothing?f=Gender%3Amen%20women%2Cwomen&p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)
# Out:
# Total pages-  5388
# Total items- 269414

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/clothing?f=Gender%3Amen%20women%2Cwomen&p={p}&plaEnabled=false&rows=50&o={p}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)
# Out:
# Exception Occured 'products'
# (268882,
#  268882,
#  268882,
#  268882,
#  268882,
#  268882,
#  268882,
#  268882,
#  268882,
#  268882)

# %%
value_tester(268881)
# Out:
# https://www.myntra.com/Kurta-Sets/Indo-Era/Indo-Era-Women-Yellow-Printed-Kurta-with-Trousers--Dupatta/13917958/buy
# 2499
# 1224
# Printed Kurta with Trousers & Dupatta
# Women
# Indo Era
# Indo Era Women Yellow Printed Kurta with Trousers & Dupatta
# http://assets.myntassets.com/assets/images/13917958/2021/4/20/2ca11ad7-3974-46e6-b4ca-fa20514ac3531618896267799-Indo-Era-Yellow-Foil-Floral-Printed-Straight-Kurta-Pant-with-1.jpg
# ['http://assets.myntassets.com/assets/images/13917958/2021/4/20/2ca11ad7-3974-46e6-b4ca-fa20514ac3531618896267799-Indo-Era-Yellow-Foil-Floral-Printed-Straight-Kurta-Pant-with-1.jpg', 'http://assets.myntassets.com/assets/images/13917958/2021/4/20/5e9a704e-d4ac-4ba5-a938-55081cdf44b81618896267778-Indo-Era-Yellow-Foil-Floral-Printed-Straight-Kurta-Pant-with-2.jpg', 'http://assets.myntassets.com/assets/images/13917958/2021/4/20/719f9155-97f1-445c-8732-7f156c33b8d21618896267733-Indo-Era-Yellow-Foil-Floral-Printed-Straight-Kurta-Pant-with-4.jpg', 'http://assets.myntassets.com/assets/images/13917958/2021/4/20/bcfe498b-f362-437e-98bc-1f348daba7d21618896267683-Indo-Era-Yellow-Foil-Floral-Printed-Straight-Kurta-Pant-with-6.jpg', 'http://assets.
# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Women Accessories

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/women-accessories?f=Categories%3AAnklet%2CBackpacks%2CBangle%2CBelts%2CBracelet%2CCufflinks%2CDuffel%20Bag%2CEarrings%2CFrames%2CGloves%2CHandbags%2CHat%2CHead%20Jewellery%2CJewellery%20Set%2CLaptop%20Bag%2CMobile%20Accessories%2CRing%2CScarves%2CSocks%2CStoles%2CSunglasses%2CWallets%2CWatches%3A%3AGender%3Amen%20women%2Cwomen&p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)
# Out:
# Total pages-  1430
# Total items- 71511

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/women-accessories?f=Categories%3AAnklet%2CBackpacks%2CBangle%2CBelts%2CBracelet%2CCufflinks%2CDuffel%20Bag%2CEarrings%2CFrames%2CGloves%2CHandbags%2CHat%2CHead%20Jewellery%2CJewellery%20Set%2CLaptop%20Bag%2CMobile%20Accessories%2CRing%2CScarves%2CSocks%2CStoles%2CSunglasses%2CWallets%2CWatches%3A%3AGender%3Amen%20women%2Cwomen&p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)
# Out:
# Exception Occured 'products'
# (71347, 71347, 71347, 71347, 71347, 71347, 71347, 71347, 71347, 71347)

# %%
value_tester(60000)
# Out:
# https://www.myntra.com/Mobile-Accessories/macmerise/macmerise-Blue--White-Marvel-Comics-Captain-America-Vintage-Suit-Sublime-Xiaomi-Redmi-Note-8-Pro-Back-Cover/12173298/buy
# 699
# 499
# Marvel Comics Captain America Vintage Suit Sublime Xiaomi Redmi Note 8 Pro Back Cover
# Unisex
# macmerise
# macmerise Blue & White Marvel Comics Captain America Vintage Suit Sublime Xiaomi Redmi Note 8 Pro Back Cover
# http://assets.myntassets.com/assets/images/productimage/2020/7/31/ef8fc0e1-6c80-4b34-91c3-005eabee56f91596147466014-1.jpg
# ['http://assets.myntassets.com/assets/images/productimage/2020/7/31/ef8fc0e1-6c80-4b34-91c3-005eabee56f91596147466014-1.jpg', '', 'http://assets.myntassets.com/assets/images/productimage/2020/7/31/8da83f9a-82bd-4ae3-961c-040f80077e381596147466077-2.jpg', 'http://assets.myntassets.com/assets/images/productimage/2020/7/31/ef8fc0e1-6c80-4b34-91c3-005eabee56f91596147466014-1.jpg']
# ['Onesize']

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()

# %% [markdown]
# # Women Jewellery

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
ses=rt.Session()
ses.get('https://www.myntra.com/t-shirts',headers=headers)
temp=ses.get('https://www.myntra.com/gateway/v2/search/women-jewellery?p=2&plaEnabled=false&rows=50&o=49',headers=headers)
data_in_json=json.loads(temp.text)
total_items=data_in_json['totalCount']
page_no=int(total_items)//50
p=1
o=0
print('Total pages- ',page_no)
print('Total items-',total_items)
# Out:
# Total pages-  575
# Total items- 28789

# %%
#to get product_names, brand_names, image_links,sizes and product_links
a=datetime.datetime.now()
brand_names={}
product_names={}
primary_image_links={}
secondary_image_links={}
product_links={}
sizes={}
mrp={}
price={}
description={}
gender={}
counter=0
for i in range(1,(page_no+1)):
    try:
        p=i
        o=(p*50)-50
        data=ses.get(f'https://www.myntra.com/gateway/v2/search/women-jewellery?p={p}&plaEnabled=false&rows=50&o={o}',headers=headers)
        data_in_json=json.loads(data.text)
        data_in_json=data_in_json['products']
        p+=1
        o+=50
        for j in range(len(data_in_json)):
            brand_names[counter]=data_in_json[j]['brand']
            product_names[counter]=data_in_json[j]['productName']
            product_links[counter]='https://www.myntra.com/'+data_in_json[j]['landingPageUrl']
            primary_image_links[counter]=data_in_json[j]['searchImage']
            mrp[counter]=data_in_json[j]['mrp']
            price[counter]=data_in_json[j]['price']
            gender[counter]=data_in_json[j]['gender']
            description[counter]=data_in_json[j]['additionalInfo']
            temp_data=data_in_json[j]['images']
            temp_links=[]
            temp_size=[]
            temp_size_data=data_in_json[j]['inventoryInfo']
            for w in temp_size_data:
                label,avail=w['label'],w['available']
                if avail== True:
                    temp_size.append(label)
            sizes[counter]=temp_size
            for k in temp_data:
                temp_links.append(k['src'])
            secondary_image_links[counter]=temp_links
            counter+=1
        time.sleep(np.random.randint(1,5))
    except Exception as e :
        print('Exception Occured',e)
        continue
b=datetime.datetime.now()
len(product_links),len(brand_names),len(product_names),len(primary_image_links),len(sizes),len(secondary_image_links),len(mrp),len(price),len(description),len(gender)
# Out:
# (28706, 28706, 28706, 28706, 28706, 28706, 28706, 28706, 28706, 28706)

# %%
value_tester(20000)
# Out:
# https://www.myntra.com/Earrings/E2O/E2O-Gold-Plated--Black-Circular-Studs/14191450/buy
# 999
# 699
# Circular Studs
# Women
# E2O
# E2O Gold-Plated & Black Circular Studs
# http://assets.myntassets.com/assets/images/productimage/2021/4/26/27172fed-d1ff-42b0-8491-bab6d4cf7f101619419177343-1.jpg
# ['http://assets.myntassets.com/assets/images/productimage/2021/4/26/27172fed-d1ff-42b0-8491-bab6d4cf7f101619419177343-1.jpg', '', 'http://assets.myntassets.com/assets/images/productimage/2021/4/26/71ca3d60-1340-4460-95ac-82d1181e1c2c1619419177385-3.jpg', 'http://assets.myntassets.com/assets/images/productimage/2021/4/26/15068171-6a91-4590-ab36-d35e5672f80a1619419177364-2.jpg', 'http://assets.myntassets.com/assets/images/productimage/2021/4/26/27172fed-d1ff-42b0-8491-bab6d4cf7f101619419177343-1.jpg']
# ['Onesize']

# %%
con=sq.connect(r'E:\GRROOM\DataBase\Myntra.db')  
cur=con.cursor()
#cur.execute('CREATE TABLE product_details (Website varchar(40) not null,Product_Link text PRIMARY KEY,Product_Name varchar(50) not null,Product_Brand varchar(50) not null,Size_Avail varchar(20) not null,Price int not null,MRP int not null,Gender varchar(15) not null,Description text not null,Primary_Image_Links text not null,Secondary_Image_Links text not null,Affiliate_Link text not null )')
for i in range(len(product_links)):
    try:
        if i in brand_names.keys() and i in product_names.keys() and i in secondary_image_links.keys() and i in sizes.keys() and i in price.keys() and i in mrp.keys() and i in description.keys() and i in gender.keys()  and i in primary_image_links.keys():
            if brand_names[i] != '' and primary_image_links[i] != ''  and product_names[i] != '' and ','.join(secondary_image_links[i]) != '' and ','.join(sizes[i]) != '' and price[i] != '' and mrp[i] != '' and brand_names[i] != '' and description[i] != '' :
                cur.execute('insert into product_details  values(%r,%r,%r,%r,%r,%d,%d,%r,%r,%r,%r,%r)'%('https://www.myntra.com/',product_links[i],product_names[i],brand_names[i],','.join(set(sizes[i])),price[i],mrp[i],gender[i],description[i],primary_image_links[i],','.join(secondary_image_links[i]),''))
    except:
        pass
con.commit()
con.close()
# Out:
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# ...
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo

# %%
# Out:
# 223899
