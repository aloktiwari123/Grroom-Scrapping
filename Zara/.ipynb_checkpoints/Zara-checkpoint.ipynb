# %%
import pandas as pd
import sqlite3
import time
import requests
import concurrent.futures
from bs4 import BeautifulSoup
import warnings
import math
warnings.filterwarnings('ignore')

# %%
# Retrieving Names of Categories
types_df = pd.read_csv("listOfTypes.csv")
categories = types_df['Type'].to_list()
categories
# Out:
# ['men-clothing',
#  'women-clothing',
#  'footwear',
#  'watches',
#  'wallets',
#  'bags',
#  'jewellery',
#  'belts',
#  'ties',
#  'cufflinks',
#  'pocket-squares',
#  'caps',
#  'hats',
#  'scarves',
#  'gloves',
#  'phones-cases',
#  'rings',
#  'wristwear',
#  'socks',
#  'bracelets',
#  'chains']

# %% [markdown]
# # Zara

# %%
base_url = "https://www.zara.com"
headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:91.0) Gecko/20100101 Firefox/91.0"}
page_url = "https://api.empathybroker.com/search/v1/query/zara/search?jsonCallback=_pdJsonpCallback_1&o=json&m=30&q={}&filter=sectionName%3A%22{}%22%20OR%20sectionName%3A%22ALL%22&filter=subsectionCode%3A%22default%22&scope=default&t=*&lang=en_GB&store=11744&catalogue=36551&warehouse=28551&section={}&start={}&rows=30&origin=default&session=7ad37610-1ec7-449f-94a8-392fb4df3e0e&user=8c9ee228-06a1-4040-8630-00243650bbc6&sort=score%20desc&sort=kpi_salesAmount_11744%20desc&hideOptionalProducts=false&contextualizeEnabled=true"
product_url = "https://www.zara.com/in/en/{}-p{}.html?v1={}"
per_page_total = 30

# %%
categ_avail = ["man", "woman", "footwear", "bags", "jewellery", "belts", "scarves", "hats", "caps"]
categ_avail
# Out:
# ['man',
#  'woman',
#  'footwear',
#  'bags',
#  'jewellery',
#  'belts',
#  'scarves',
#  'hats',
#  'caps']

# %%
def get_page_nums(categories):
    
    keyword = '"numFound":'
    page_nums_man = []
    page_nums_woman = []
    
    print("For men's gender :- \n")
    for category in categories:
        res = requests.session().get(page_url.format(category, "MAN", "MAN", "0")).text
        index = res.find(keyword)+len(keyword)
        total = math.ceil(int(res[index:index + res[index:].find(",")])/per_page_total)
        print(category, total)
        page_nums_man.append(total)
    
    print("\nWomen's gender :- \n")
    for category in categories:
        res = requests.session().get(page_url.format(category, "WOMAN", "WOMAN", "0")).text
        index = res.find(keyword)+len(keyword)
        total = math.ceil(int(res[index:index + res[index:].find(",")])/per_page_total)
        print(category, total)
        page_nums_woman.append(total)
    
    return page_nums_man, page_nums_woman

page_nums_man, page_nums_woman = get_page_nums(categ_avail)
# Out:
# For men's gender :-
#
# man 78
# woman 0
# footwear 9
# bags 9
# jewellery 1
# belts 2
# scarves 1
# hats 2
# caps 2
#
# Women's gender :-
#
# man 0
# woman 167
# footwear 17
# bags 15
# jewellery 5
# belts 7
# scarves 2
# hats 2
# caps 3

# %%
def get_prod_urls(page_data, categ):
    
    results = page_data.split('"seo":')[1:]
    prod_urls = []
    
    for item in results:
        
        try:
            key1 = '"keyword":"'
            key2 = '"seoProductId":"'
            key3 = '"discernProductId":"'    

            item1 = item[item.find(key1)+len(key1):item.find('","seoProductId":"')]
            item2 = item[item.find(key2)+len(key2):item.find('","discernProductId"')]
            item3 = item[item.find(key3)+len(key3):item.find('"},"ebTagging"')]
            
            req_url = product_url.format(item1, item2, item3)
            prod_urls.append([req_url, categ_avail[categ]])
            
        except:
            continue
    
    return prod_urls

# %%
urls_men = []
urls_women = []

start = time.time()


for gender in ['man', 'woman']:
    
    if gender == 'man':
        print("Now retrieving men's products\n")
        for categ in range(len(categ_avail)):
            count = 0
            categ_num = page_nums_man[categ]
            for page_num in range(categ_num):
                page_data = requests.session().get(page_url.format(categ_avail[categ], "MAN", "MAN", str(page_num*30))).text
                urls_men.extend(get_prod_urls(page_data, categ))
            
            print("Category:- {} Done".format(categ_avail[categ]))
            print("Time Elapsed {} mins\n".format(round((time.time() - start)/60, 2)))
            
    else:
        start_ = time.time()
        print("\n" + "*"*100 + "\n")
        print("Now retrieving women's products\n")   
        
        for categ in range(len(categ_avail)):
            
            categ_num = page_nums_woman[categ]
            for page_num in range(categ_num):
                page_data = requests.session().get(page_url.format(categ_avail[categ], "WOMAN", "WOMAN", str(page_num*30))).text
                urls_women.extend(get_prod_urls(page_data, categ))
                
            print("Category:- {} Done".format(categ_avail[categ]))
            print("Time Elapsed {} mins\n".format(round((time.time() - start_)/60, 2)))   
            
    print("Total Time Elapsed {} mins\n".format(round((time.time() - start)/60, 2)))
# Out:
# Now retrieving men's products
#
# Category:- man Done
# Time Elapsed 0.89 mins
#
# Category:- woman Done
# Time Elapsed 0.89 mins
#
# Category:- footwear Done
# Time Elapsed 1.01 mins
#
# Category:- bags Done
# Time Elapsed 1.12 mins
#
# Category:- jewellery Done
# Time Elapsed 1.13 mins
#
# Category:- belts Done
# Time Elapsed 1.17 mins
#
# Category:- scarves Done
# Time Elapsed 1.18 mins
#
# Category:- hats Done
# Time Elapsed 1.22 mins
#
# Category:- caps Done
# Time Elapsed 1.25 mins
#
# Total Time Elapsed 1.25 mins
#
#
# ****************************************************************************************************
#
# Now retrieving women's products
#
# Category:- man Done
# Time Elapsed 0.0 mins
#
# Category:- woman Done
# Time Elapsed 1.29 mins
#
# Category:- footwear Done
# Time Elapsed 1.46 mins
#
# Category:- bags Done
# Time Elapsed 1.54 mins
#
# Category:- jewellery Done
# Time Elapsed 1.6 mins
#
# Category:- belts Done
# Time Elapsed 1.72 mins
#
# Category:- scarves Done
# Time Elapsed 1.75 mins
#
# Category:- hats Done
# Time Elapsed 1.78 mins
#
# Category:- caps Done
# Time Elapsed 1.84 mins
#
# Total Time Elapsed 3.09 mins

# %%
def extract(url, cat, gender):
    
    time.sleep(0.2)
    r = requests.session().get(url, headers=headers).text
    soup = BeautifulSoup(r, "html.parser")
    
    item = soup.find_all("script")
    
    item1 = str(item[22])
    item2 = str(item[23])
    
    
    try:
        
        website = base_url

        #product link
        keyword = '"url":"'
        index = item1.find(keyword)+len(keyword)
        product_link = item1[index:index + item1[index:].find('"')]

        #product name
        keyword = '"name":"'
        index = item1.find(keyword)+len(keyword)
        product_name = item1[index:index + item1[index:].find('"')]

        #product brand
        keyword = '"brand":"'
        index = item1.find(keyword)+len(keyword)
        product_brand = item1[index:index + item1[index:].find('"')]

        #product category
        product_category = cat

        #sizes available

        sizes = []

        keyword = '"sizes":[{"'
        index = item2.find('"sizes":[{"') + len(keyword)
        req_text = item2[index: index + item2[index:].find(']')]

        while True:
            keyword = 'availability":"in_stock"'
            index = req_text.find(keyword)
            if index != -1:
                req_text = req_text[index+len(keyword):]
                keyword = '"name":"'
                index = req_text.find(keyword) + len(keyword)
                sizes.append(req_text[index:index + req_text[index:].find('"')]) 
                req_text = req_text[index+4:]
            else:
                break

        if len(sizes) == 0:
            print("here")
            sizes = "ONE SIZE"
        else:
            sizes = ",".join(sizes)

        #price
        keyword = '"price":"'
        index = item1.find(keyword)+len(keyword)
        price = item1[index:index + item1[index:].find('"')]

        #mrp
        mrp = price

        #gender
        gender = gender

        #description
        keyword = '"description":"'
        index = item1.find(keyword)+len(keyword)
        description = item1[index:index + item1[index:].find('"')].strip('\\n')
        description = item1[index:index + item1[index:].find('"')].strip('\n')


        """IMAGES"""

        keyword = '"image":["'
        index = item1.find(keyword) + len(keyword)
        req_text = item1[index: index + item1[index:].find(']')]
        images = req_text.split('","')[:-1]

        #primary image
        p_link = images[0]

        #secondary images
        sec_links = images[1:]
        sec_links = ",".join(sec_links)
        
        if sec_links == None:
            sec_links = "not available"

        final_results = [website, product_link, product_name, product_brand, product_category, sizes,
                    price, mrp, gender, description, p_link, sec_links]

        data.append(final_results)

    except:
        pass

# %%
# Create a base CSV file for storing
columns = ["Website", "Product_Link", "Product_Name", "Product_Brand", "Product_Category", "Size_Avail", "Price",
          "MRP", "Gender", "Description", "Primary_Image_Links", "Secondary_Image_Links"]

base_df = pd.DataFrame(columns=columns)
base_df.to_csv("zara.csv", index=False)

# %%
"""
MAIN FUNCTION
"""

data = []
counter = 0
start = time.time()

jump = 5


"""
Men's section
"""

print("Now retrieving men's products \n")

for pivot in range(0, len(urls_men), jump):
    
    prod_urls = []
    prod_cats = []
    gender_lst = ["men"] * jump
    temp_lst = urls_men[pivot:pivot+jump]
    
    for i in temp_lst:
        prod_urls.append(i[0])
        if i[1] == 'man':
            prod_cats.append('men clothing')
        else:
            prod_cats.append(i[1])
    with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(extract, prod_urls, prod_cats, gender_lst)
    
    counter += (len(prod_urls))
    
    if counter % 50 == 0:
        print("Total Amount scraped :- ", counter, sep="  ")
        print("Current Category:- ", prod_cats[-1])
        print("\nTime Elapsed:- ", round((time.time() - start)/60, 2), "mins\n")
        print()

    # Adding to CSV for every page result
    temp_df = pd.DataFrame(data, columns=columns)
    temp_df.to_csv('zara.csv', mode='a', header=False, index=False)

    # Re-initializing list for next page
    data = []

end = time.time()
print("\nTotal Time Elapsed:- ", round((end - start)/60, 2), "mins\n\n")


"""
Women's section
"""
data = []
counter = 0
start = time.time()

print("Now retrieving women's products \n")

for pivot in range(0, len(urls_women), jump):
    
    prod_urls = []
    prod_cats = []
    gender_lst = ["women"] * jump
    
    temp_lst = urls_women[pivot:pivot+jump]
    
    for i in temp_lst:
        prod_urls.append(i[0])
        if i[1] == 'woman':
            prod_cats.append('women clothing')
        else:
            prod_cats.append(i[1])
    with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(extract, prod_urls, prod_cats, gender_lst)
    
    counter += (len(prod_urls))
    
    if counter % 50 == 0:
        print("Total Amount scraped :- ", counter, sep="  ")
        print("Current Category:- ", prod_cats[-1])
        print("\nTime Elapsed:- ", round((time.time() - start)/60, 2), "mins\n")
        print()

    # Adding to CSV for every page result
    temp_df = pd.DataFrame(data, columns=columns)
    temp_df.to_csv('zara.csv', mode='a', header=False, index=False)

    # Re-initializing list for next page
    data = []

end = time.time()
print("\nTotal Time Elapsed:- ", round((end - start)/60, 2), "mins\n")
# Out:
# Now retrieving men's products
#
# here
# Total Amount scraped :-   50
# Current Category:-  men clothing
#
# Time Elapsed:-  0.18 mins
#
#
# Total Amount scraped :-   100
# Current Category:-  men clothing
#
# Time Elapsed:-  0.36 mins
#
#
# Total Amount scraped :-   150
# Current Category:-  men clothing
#
# Time Elapsed:-  0.57 mins
#
#
# Total Amount scraped :-   200
# Current Category:-  men clothing
#
# Time Elapsed:-  0.78 mins
#
#
# Total Amount scraped :-   250
# Current Category:-  men clothing
#
# Time Elapsed:-  0.99 mins
#
#
# Total Amount scraped :-   300
# Current Category:-  men clothing
#
# Time Elapsed:-  1.21 mins
#
#
# Total Amount scraped :-   350
# Current Category:-  men clothing
#
# Time Elapsed:-  1.4 mins
#
#
# Total Amount scraped :-   400
# Current Category:-  men clothing
#
# Time Elapsed:-  1.6 mins
#
#
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   450
# Current Category:-  men clothing
#
# Time Elapsed:-  1.79 mins
#
#
# Total Amount scraped :-   500
# Current Category:-  men clothing
#
# Time Elapsed:-  1.99 mins
#
#
# Total Amount scraped :-   550
# Current Category:-  men clothing
#
# Time Elapsed:-  2.2 mins
#
#
# here
# Total Amount scraped :-   600
# Current Category:-  men clothing
#
# Time Elapsed:-  2.43 mins
#
#
# Total Amount scraped :-   650
# Current Category:-  men clothing
#
# Time Elapsed:-  2.61 mins
#
#
# Total Amount scraped :-   700
# Current Category:-  men clothing
#
# Time Elapsed:-  2.81 mins
#
#
# Total Amount scraped :-   750
# Current Category:-  men clothing
#
# Time Elapsed:-  3.01 mins
#
#
# here
# here
# Total Amount scraped :-   800
# Current Category:-  men clothing
#
# Time Elapsed:-  3.21 mins
#
#
# here
# here
# Total Amount scraped :-   850
# Current Category:-  men clothing
#
# Time Elapsed:-  3.39 mins
#
#
# here
# Total Amount scraped :-   900
# Current Category:-  men clothing
#
# Time Elapsed:-  3.59 mins
#
#
# Total Amount scraped :-   950
# Current Category:-  men clothing
#
# Time Elapsed:-  3.78 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1000
# Current Category:-  men clothing
#
# Time Elapsed:-  3.96 mins
#
#
# Total Amount scraped :-   1050
# Current Category:-  footwear
#
# Time Elapsed:-  4.15 mins
#
#
# here
# here
# Total Amount scraped :-   1100
# Current Category:-  footwear
#
# Time Elapsed:-  4.34 mins
#
#
# Total Amount scraped :-   1150
# Current Category:-  footwear
#
# Time Elapsed:-  4.54 mins
#
#
# Total Amount scraped :-   1200
# Current Category:-  footwear
#
# Time Elapsed:-  4.72 mins
#
#
# here
# Total Amount scraped :-   1250
# Current Category:-  footwear
#
# Time Elapsed:-  4.91 mins
#
#
# here
# here
# here
# here
# Total Amount scraped :-   1300
# Current Category:-  bags
#
# Time Elapsed:-  5.09 mins
#
#
# here
# Total Amount scraped :-   1350
# Current Category:-  bags
#
# Time Elapsed:-  5.26 mins
#
#
# here
# here
# here
# Total Amount scraped :-   1400
# Current Category:-  bags
#
# Time Elapsed:-  5.44 mins
#
#
# Total Amount scraped :-   1450
# Current Category:-  bags
#
# Time Elapsed:-  5.62 mins
#
#
# here
# Total Amount scraped :-   1500
# Current Category:-  bags
#
# Time Elapsed:-  5.79 mins
#
#
# here
# Total Amount scraped :-   1550
# Current Category:-  bags
#
# Time Elapsed:-  5.98 mins
#
#
# Total Amount scraped :-   1600
# Current Category:-  belts
#
# Time Elapsed:-  6.13 mins
#
#
# here
# here
# Total Amount scraped :-   1650
# Current Category:-  hats
#
# Time Elapsed:-  6.31 mins
#
#
# here
# here
# Total Amount scraped :-   1700
# Current Category:-  caps
#
# Time Elapsed:-  6.42 mins
#
#
#
# Total Time Elapsed:-  6.42 mins
#
#
# Now retrieving women's products
#
# here
# here
# Total Amount scraped :-   50
# Current Category:-  women clothing
#
# Time Elapsed:-  0.18 mins
#
#
# here
# here
# here
# Total Amount scraped :-   100
# Current Category:-  women clothing
#
# Time Elapsed:-  0.38 mins
#
#
# here
# here
# here
# Total Amount scraped :-   150
# Current Category:-  women clothing
#
# Time Elapsed:-  0.6 mins
#
#
# here
# Total Amount scraped :-   200
# Current Category:-  women clothing
#
# Time Elapsed:-  0.8 mins
#
#
# here
# Total Amount scraped :-   250
# Current Category:-  women clothing
#
# Time Elapsed:-  1.02 mins
#
#
# here
# here
# here
# here
# here
# Total Amount scraped :-   300
# Current Category:-  women clothing
#
# Time Elapsed:-  1.2 mins
#
#
# here
# here
# here
# here
# here
# Total Amount scraped :-   350
# Current Category:-  women clothing
#
# Time Elapsed:-  1.39 mins
#
#
# Total Amount scraped :-   400
# Current Category:-  women clothing
#
# Time Elapsed:-  1.57 mins
#
#
# here
# here
# Total Amount scraped :-   450
# Current Category:-  women clothing
#
# Time Elapsed:-  1.77 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   500
# Current Category:-  women clothing
#
# Time Elapsed:-  1.96 mins
#
#
# here
# here
# here
# Total Amount scraped :-   550
# Current Category:-  women clothing
#
# Time Elapsed:-  2.17 mins
#
#
# here
# Total Amount scraped :-   600
# Current Category:-  women clothing
#
# Time Elapsed:-  2.36 mins
#
#
# Total Amount scraped :-   650
# Current Category:-  women clothing
#
# Time Elapsed:-  2.56 mins
#
#
# here
# Total Amount scraped :-   700
# Current Category:-  women clothing
#
# Time Elapsed:-  2.75 mins
#
#
# Total Amount scraped :-   750
# Current Category:-  women clothing
#
# Time Elapsed:-  2.94 mins
#
#
# here
# Total Amount scraped :-   800
# Current Category:-  women clothing
#
# Time Elapsed:-  3.13 mins
#
#
# here
# here
# here
# Total Amount scraped :-   850
# Current Category:-  women clothing
#
# Time Elapsed:-  3.34 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   900
# Current Category:-  women clothing
#
# Time Elapsed:-  3.53 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   950
# Current Category:-  women clothing
#
# Time Elapsed:-  3.75 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1000
# Current Category:-  women clothing
#
# Time Elapsed:-  3.95 mins
#
#
# here
# here
# here
# Total Amount scraped :-   1050
# Current Category:-  footwear
#
# Time Elapsed:-  4.15 mins
#
#
# here
# here
# here
# here
# here
# Total Amount scraped :-   1100
# Current Category:-  footwear
#
# Time Elapsed:-  4.36 mins
#
#
# here
# here
# Total Amount scraped :-   1150
# Current Category:-  footwear
#
# Time Elapsed:-  4.57 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1200
# Current Category:-  footwear
#
# Time Elapsed:-  4.77 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1250
# Current Category:-  footwear
#
# Time Elapsed:-  4.99 mins
#
#
# Total Amount scraped :-   1300
# Current Category:-  footwear
#
# Time Elapsed:-  5.18 mins
#
#
# here
# here
# here
# here
# Total Amount scraped :-   1350
# Current Category:-  footwear
#
# Time Elapsed:-  5.36 mins
#
#
# here
# Total Amount scraped :-   1400
# Current Category:-  footwear
#
# Time Elapsed:-  5.56 mins
#
#
# here
# here
# Total Amount scraped :-   1450
# Current Category:-  footwear
#
# Time Elapsed:-  5.74 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1500
# Current Category:-  footwear
#
# Time Elapsed:-  5.92 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1550
# Current Category:-  bags
#
# Time Elapsed:-  6.09 mins
#
#
# here
# Total Amount scraped :-   1600
# Current Category:-  bags
#
# Time Elapsed:-  6.27 mins
#
#
# Total Amount scraped :-   1650
# Current Category:-  bags
#
# Time Elapsed:-  6.46 mins
#
#
# here
# here
# here
# here
# here
# Total Amount scraped :-   1700
# Current Category:-  bags
#
# Time Elapsed:-  6.64 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1750
# Current Category:-  bags
#
# Time Elapsed:-  6.81 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1800
# Current Category:-  bags
#
# Time Elapsed:-  6.97 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1850
# Current Category:-  bags
#
# Time Elapsed:-  7.1 mins
#
#
# Total Amount scraped :-   1900
# Current Category:-  bags
#
# Time Elapsed:-  7.2 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   1950
# Current Category:-  bags
#
# Time Elapsed:-  7.3 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   2000
# Current Category:-  jewellery
#
# Time Elapsed:-  7.48 mins
# Total Amount scraped :-   2050
# Current Category:-  jewellery
#
# Time Elapsed:-  7.65 mins
#
#
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   2100
# Current Category:-  belts
#
# Time Elapsed:-  7.81 mins
#
#
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   2150
# Current Category:-  belts
#
# Time Elapsed:-  7.99 mins
#
#
# here
# here
# here
# here
# here
# here
# Total Amount scraped :-   2200
# Current Category:-  belts
#
# Time Elapsed:-  8.16 mins
#
#
# Total Amount scraped :-   2250
# Current Category:-  belts
#
# Time Elapsed:-  8.34 mins
#
#
# here
# here
# here
# Total Amount scraped :-   2300
# Current Category:-  scarves
#
# Time Elapsed:-  8.69 mins
#
#
# here
# here
# Total Amount scraped :-   2350
# Current Category:-  hats
#
# Time Elapsed:-  8.9 mins
#
#
# here
# Total Amount scraped :-   2400
# Current Category:-  caps
#
# Time Elapsed:-  9.09 mins
#
#
# here
# here
# here
# Total Amount scraped :-   2450
# Current Category:-  caps
#
# Time Elapsed:-  9.21 mins
#
#
# here
#
# Total Time Elapsed:-  9.27 mins

# %% [markdown]
# # Dataframes

# %%
df = pd.read_csv("zara.csv")
df = df.drop_duplicates()
df.dropna(inplace = True)
df["Affiliate_Link"] = [None]*df.shape[0]
df
# Out:
#                    Website                                       Product_Link  \
# 0     https://www.zara.com  https://www.zara.com/in/en/man-silver-100ml-p2...
# 1     https://www.zara.com  https://www.zara.com/in/en/man-silver-man-uomo...
# 2     https://www.zara.com  https://www.zara.com/in/en/man-gold-100-ml-p20...
# 3     https://www.zara.com  https://www.zara.com/in/en/man-blue-spirit-30-...
# 4     https://www.zara.com  https://www.zara.com/in/en/man-blue-spirit-100...
# ...                    ...                                                ...
# 4156  https://www.zara.com  https://www.zara.com/in/en/violet-blossom-10ml...
# 4157  https://www.zara.com  https://www.zara.com/in/en/violet-blossom-200-...
# 4158  https://www.zara.com  https://www.zara.com/in/en/zara-nuit-eau-de-pa...
# 4159  https://www.zara.com  https://www.zara.com/in/en/rigid-carry-on-suit...
# 4160  https://www.zara.com  https://www.zara.com/in/en/rigid-carry-on-suit...
#
#                                Product_Name Product_Brand Product_Category  \
# 0                          MAN SILVER 100ML          ZARA     men clothing
# 1     MAN SILVER + MAN UOMO 100ML / 3.38 oz          ZARA     men clothing
# 2                           MAN GOLD 100 ML          ZARA     men clothing
# 3                     MAN BLUE SPIRIT 30 ML          ZARA     men clothing
# 4                    MAN BLUE SPIRIT 100 ML          ZARA     men clothing
# ...                                     ...           ...              ...
# 4156          VIOLET BLOSSOM 10ML / 0.34 oz          ZARA             caps
# 4157        VIOLET BLOSSOM 200 ML / 6.76 oz          ZARA             caps
# 4158        ZARA  NUIT EAU DE PARFUM 100 ML          ZARA             caps
# 4159                RIGID CARRY-ON SUITCASE          ZARA             caps
# 4160                RIGID CARRY-ON SUITCASE          ZARA             caps
#
#          Size_Avail Price   MRP Gender  \
# 0     ONE SIZE ONLY   990   990    men
# 1     ONE SIZE ONLY  1290  1290    men
# 2     ONE SIZE ONLY   990   990    men
# 3     ONE SIZE ONLY   590   590    men
# 4     ONE SIZE ONLY   990   990    men
# ...             ...   ...   ...    ...
# 4156  ONE SIZE ONLY   390   390  women
# 4157  ONE SIZE ONLY  1290  1290  women
# 4158  ONE SIZE ONLY   990   990  women
# 4159  ONE SIZE ONLY  6990  6990  women
# 4160  ONE SIZE ONLY  6990  6990  women
#
#                                             Description  \
# 0     ZARA MAN SILVER EDT 100 ML (3.4 FL. OZ). \n\nA...
# 1     ZARA MAN SILVER + ZARA MAN UOMO EDT 100 ML (3....
# 2     ZARA MAN UOMO EAU DE TOILETTE 100 ML (3.4 FL. ...
# 3     ZARA MAN BLUE SPIRIT EDT 30 ML (1.02 FL. OZ). ...
# 4     ZARA MAN BLUE SPIRIT EAU DE TOILETTE 100 ML (3...
# ...                                                 ...
# 4156  ZARA VIOLET BLOSSOM EDP 10 ML (0.34 FL. OZ). \...
# 4157  ZARA VIOLET BLOSSOM EDP 200 ML (6.8 FL. OZ). \...
# 4158  ZARA NUIT EDP 100 ML (3.4 FL. OZ). \n\nEau de ...
# 4159  Travel trolley suitcase. The main compartment ...
# 4160  Travel trolley suitcase. The main compartment ...
#
#                                     Primary_Image_Links  \
# 0     https://static.zara.net/photos///2021/V/2/2/p/...
# 1     https://static.zara.net/photos///2021/V/2/2/p/...
# 2     https://static.zara.net/photos///2021/V/2/2/p/...
# 3     https://static.zara.net/photos///2021/V/2/2/p/...
# 4     https://static.zara.net/photos///2021/V/2/2/p/...
# ...                                                 ...
# 4156  https://static.zara.net/photos///2019/I/2/1/p/...
# 4157  https://static.zara.net/photos///2019/I/2/1/p/...
# 4158  https://static.zara.net/photos///2021/V/2/1/p/...
# 4159  https://static.zara.net/photos///2021/I/1/2/p/...
# 4160  https://static.zara.net/photos///2021/V/1/2/p/...
#
#                                   Secondary_Image_Links Affiliate_Link
# 0     https://static.zara.net/photos///2021/V/2/2/p/...           None
# 1     https://static.zara.net/photos///2021/V/2/2/p/...           None
# 2     https://static.zara.net/photos///2021/V/2/2/p/...           None
# 3     https://static.zara.net/photos///2020/V/2/2/p/...           None
# 4     https://static.zara.net/photos///2021/V/2/2/p/...           None
# ...                                                 ...            ...
# 4156  https://static.zara.net/photos///2019/I/2/1/p/...           None
# 4157  https://static.zara.net/photos///2019/I/2/1/p/...           None
# 4158  https://static.zara.net/photos///2021/V/2/1/p/...           None
# 4159  https://static.zara.net/photos///2021/I/1/2/p/...           None
# 4160  https://static.zara.net/photos///2021/V/1/2/p/...           None
#
# [4087 rows x 13 columns]

# %%
conn = sqlite3.connect('ZaraProducts.db')
c = conn.cursor()

# %%
c.execute('CREATE TABLE product_details (Website varchar(40) NOT NULL, Product_Link TEXT PRIMARY KEY,Product_Name varchar(50) NOT NULL,Product_Brand varchar(50) NOT NULL,Product_Category varchar(50),Size_Avail varchar(20) NOT NULL,Price int NOT NULL,MRP int NOT NULL,Gender varchar(15) NOT NULL,Description TEXT NOT NULL,Primary_Image_Links TEXT NOT NULL,Secondary_Image_Links TEXT NOT NULL,Affiliate_Link TEXT NOT NULL)')
conn.commit()

# %%
df.to_sql('product_details', conn, if_exists='replace', index = False)

# %%
# Print 20 products
c.execute('''  
SELECT * FROM product_details
          ''')

for row in c.fetchmany(size=20):
    print (row)
# Out:
# ('https://www.zara.com', 'https://www.zara.com/in/en/man-silver-100ml-p20210005.html', 'MAN SILVER 100ML', 'ZARA', 'men clothing', 'ONE SIZE ONLY', '990', '990', 'men', 'ZARA MAN SILVER EDT 100 ML (3.4 FL. OZ). \\n\\nAromatic eau de toilette. The scent reveals notes of neroli flower, pepper and sandalwood. It’s a fresh, modern and luminous fragrance.', 'https://static.zara.net/photos///2021/V/2/2/p/0210/005/999/2/w/1920/0210005999_1_1_1.jpg?ts=1610530845346', 'https://static.zara.net/photos///2021/V/2/2/p/0210/005/999/2/w/1920/0210005999_2_1_1.jpg?ts=1611765402922,https://static.zara.net/photos///2021/V/2/2/p/0210/005/999/2/w/1920/0210005999_2_2_1.jpg?ts=1610530847518', None)
# ('https://www.zara.com', 'https://www.zara.com/in/en