# %%
import pandas as pd
import sqlite3
import time
import requests
import concurrent.futures
from bs4 import BeautifulSoup
import warnings
import math
warnings.filterwarnings('ignore')

# %%
#Retrieving Names of Categories
types_df = pd.read_csv("BananaRepublic listOfTypes.csv")
categories = types_df['Type'].to_list()
categories
# Out:
# ['men-clothing',
#  'women-clothing',
#  'footwear',
#  'watches',
#  'wallets',
#  'bags',
#  'jewellery',
#  'belts',
#  'ties',
#  'cufflinks',
#  'pocket-squares',
#  'caps',
#  'hats',
#  'scarves',
#  'gloves',
#  'phones-cases',
#  'rings',
#  'wristwear',
#  'socks',
#  'bracelets',
#  'chains']

# %%
# Gender Seperation
men_categories = ['men-clothing']
men_categories.extend(["men-" + cat for cat in categories[2:]])
women_categories = ['women-clothing']
women_categories.extend(["women-" + cat for cat in categories[2:]])

# %%
base_url = "https://bananarepublic.gap.com"
headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:91.0) Gecko/20100101 Firefox/91.0"}
per_page_total = 200
main_url = "https://core.dxpapi.com/api/v1/core/?account_id=6105&auth_key=&domain_key=bananarepublic&request_id=2803065648391&_br_uid_2=uid%3D9716267812900%3Av%3D12.0%3Ats%3D1630514037116%3Ahc%3D20&url=https://bananarepublic.gap.com/index.html%23brm-search%3Frequest_type=search&search_type=keyword&q={}&l={}&br_origin=searchbox&realm=prod&ref_url=https://bananarepublic.gap.com/&request_type=search&rows=200&start={}&facet.limit=300&fl=sku_color,style_color_id,sku_sizes,swatch_image_attribute,pid,title,brand,price,maxSalePrice,minSalePrice,sale_price,price_type,promotions,thumb_image,sku_thumb_images,sku_swatch_images,sku_color_group,url,price_range,sale_price_range,description,is_live,score,defaultColorMarketingMessage,styleMarketingMessage&stats.field=sale_price&segment=customer_tier:160481&"

# %%
#Number of pages
def get_page_nums(categories):
    
    nums_lst = []
    
    for category in categories:
        
        res = requests.session().get(main_url.format(category, category, "0")).json()
        pages_total = math.ceil(res['response']['numFound']/per_page_total)
        print(category, " :- ", pages_total)
        nums_lst.append(pages_total)
    
    return nums_lst

print("Per Page Total products = \n", per_page_total)
page_nums_men = get_page_nums(men_categories)
print("\n")
page_nums_women = get_page_nums(women_categories)
# Out:
# Per Page Total products =
#  200
# men-clothing  :-  4
# men-footwear  :-  1
# men-watches  :-  0
# men-wallets  :-  1
# men-bags  :-  1
# men-jewellery  :-  0
# men-belts  :-  1
# men-ties  :-  1
# men-cufflinks  :-  1
# men-pocket-squares  :-  1
# men-caps  :-  1
# men-hats  :-  1
# men-scarves  :-  1
# men-gloves  :-  1
# men-phones-cases  :-  0
# men-rings  :-  1
# men-wristwear  :-  0
# men-socks  :-  1
# men-bracelets  :-  0
# men-chains  :-  0
#
#
# women-clothing  :-  8
# women-footwear  :-  1
# women-watches  :-  1
# women-wallets  :-  1
# women-bags  :-  1
# women-jewellery  :-  0
# women-belts  :-  2
# women-ties  :-  1
# women-cufflinks  :-  0
# women-pocket-squares  :-  1
# women-caps  :-  1
# women-hats  :-  1
# women-scarves  :-  1
# women-gloves  :-  1
# women-phones-cases  :-  1
# women-rings  :-  1
# women-wristwear  :-  0
# women-socks  :-  1
# women-bracelets  :-  1
# women-chains  :-  1

# %%
def extract(item, cat, gender):
    
    try:
        website = base_url

        # product link
        product_link = base_url + item['url']

        # product name
        product_name = item['title']

        # product brand
        product_brand = "Banana Republic"
        if item['brand'] != "":
            product_brand = item['brand']

        # product category
        product_category = cat

        # sizes available
        sizes = []
        
        for size in item['variants'][0]['sku_sizes']:
            sizes.append(size)

        sizes = ",".join(sizes)
        
        
        # price
        price = item['minSalePrice']

        # mrp
        mrp = price

        # gender
        gender = gender
        
        
        # description
        temp_description = item['description'].replace('\\u', ' ').replace('\\', '').replace('002c', '')
        find_key = "."
        index = temp_description.find(find_key)
        description = temp_description[2:index]
        
        
        # primary image link
        p_img_link = item['thumb_image']

        # secondary image links
        sec_links = []
        for elem in item['variants']:
            for img in elem['sku_thumb_images']:
                sec_links.append(base_url + img)

        sec_links = ",".join(sec_links)

        final_results = [website, product_link, product_name, product_brand, product_category, sizes,
                        price, mrp, gender, description, p_img_link, sec_links]

        data.append(final_results)
    
    except:
#         print('here')
        pass

# %%
# CSV initialize
columns = ["Website", "Product_Link", "Product_Name", "Product_Brand", "Product_Category", "Size_Avail", "Price",
          "MRP", "Gender", "Description", "Primary_Image_Links", "Secondary_Image_Links"]

base_df = pd.DataFrame(columns=columns)
base_df.to_csv("bananarep.csv", index=False)

# %%
"""
Main Function 
"""


"""
Men's Section
"""

data = []

counter = 0
start = time.time()

for category in range(len(men_categories)):
    
    for page in range(page_nums_men[category]):
        
        page_data = requests.session().get(main_url.format(men_categories[category], men_categories[category], str(page*per_page_total))).json()
        
        for product in page_data['response']['docs']:
            extract(product, men_categories[category], "men")
        
        counter += len(data)
        
        temp_df = pd.DataFrame(data, columns=columns)
        temp_df.to_csv('bananarep.csv', mode='a', header=False, index=False)
        
        print("Total Amount scraped :- ", counter, sep="  ")
        print("Current Category:- ", men_categories[category])
        print("\nTime Elapsed:- ", round((time.time() - start)/60, 2), "mins\n")
        print()
        
        data = []
    

end = time.time()
print("\nTotal Time Elapsed:- ", round((time.time() - start)/60, 2), "mins\n\n")


"""
Women's Section
"""


data = []

counter = 0
start = time.time()

for category in range(len(women_categories)):
    
    for page in range(page_nums_women[category]):
        
        page_data = requests.session().get(main_url.format(women_categories[category], women_categories[category], str(page*per_page_total))).json()
        
        for product in page_data['response']['docs']:
            extract(product, women_categories[category], "women")
        
        counter += len(data)
        
        temp_df = pd.DataFrame(data, columns=columns)
        temp_df.to_csv('bananarep.csv', mode='a', header=False, index=False)
        
        print("Total Amount scraped :- ", counter, sep="  ")
        print("Current Category:- ", women_categories[category])
        print("\nTime Elapsed:- ", round((time.time() - start)/60, 2), "mins\n")
        print()
        
        data = []
    

end = time.time()
print("\nTotal Time Elapsed:- ", round((time.time() - start)/60, 2), "mins\n\n")
# Out:
# Total Amount scraped :-   200
# Current Category:-  men-clothing
#
# Time Elapsed:-  0.03 mins
#
#
# Total Amount scraped :-   400
# Current Category:-  men-clothing
#
# Time Elapsed:-  0.06 mins
#
#
# Total Amount scraped :-   600
# Current Category:-  men-clothing
#
# Time Elapsed:-  0.09 mins
#
#
# Total Amount scraped :-   699
# Current Category:-  men-clothing
#
# Time Elapsed:-  0.12 mins
#
#
# Total Amount scraped :-   724
# Current Category:-  men-footwear
#
# Time Elapsed:-  0.14 mins
#
#
# Total Amount scraped :-   728
# Current Category:-  men-wallets
#
# Time Elapsed:-  0.15 mins
#
#
# Total Amount scraped :-   743
# Current Category:-  men-bags
#
# Time Elapsed:-  0.17 mins
#
#
# Total Amount scraped :-   809
# Current Category:-  men-belts
#
# Time Elapsed:-  0.2 mins
#
#
# Total Amount scraped :-   839
# Current Category:-  men-ties
#
# Time Elapsed:-  0.21 mins
#
#
# Total Amount scraped :-   842
# Current Category:-  men-cufflinks
#
# Time Elapsed:-  0.23 mins
#
#
# Total Amount scraped :-   851
# Current Category:-  men-pocket-squares
#
# Time Elapsed:-  0.25 mins
#
#
# Total Amount scraped :-   856
# Current Category:-  men-caps
#
# Time Elapsed:-  0.27 mins
#
#
# Total Amount scraped :-   860
# Current Category:-  men-hats
#
# Time Elapsed:-  0.29 mins
#
#
# Total Amount scraped :-   871
# Current Category:-  men-scarves
#
# Time Elapsed:-  0.31 mins
#
#
# Total Amount scraped :-   872
# Current Category:-  men-gloves
#
# Time Elapsed:-  0.33 mins
#
#
# Total Amount scraped :-   874
# Current Category:-  men-rings
#
# Time Elapsed:-  0.35 mins
#
#
# Total Amount scraped :-   924
# Current Category:-  men-socks
#
# Time Elapsed:-  0.37 mins
#
#
#
# Total Time Elapsed:-  0.37 mins
#
#
# Total Amount scraped :-   200
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.03 mins
#
#
# Total Amount scraped :-   400
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.06 mins
#
#
# Total Amount scraped :-   600
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.09 mins
#
#
# Total Amount scraped :-   800
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.12 mins
#
#
# Total Amount scraped :-   1000
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.15 mins
#
#
# Total Amount scraped :-   1200
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.18 mins
#
#
# Total Amount scraped :-   1400
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.21 mins
#
#
# Total Amount scraped :-   1562
# Current Category:-  women-clothing
#
# Time Elapsed:-  0.24 mins
#
#
# Total Amount scraped :-   1583
# Current Category:-  women-footwear
#
# Time Elapsed:-  0.26 mins
#
#
# Total Amount scraped :-   1584
# Current Category:-  women-watches
#
# Time Elapsed:-  0.28 mins
#
#
# Total Amount scraped :-   1585
# Current Category:-  women-wallets
#
# Time Elapsed:-  0.3 mins
#
#
# Total Amount scraped :-   1632
# Current Category:-  women-bags
#
# Time Elapsed:-  0.32 mins
#
#
# Total Amount scraped :-   1832
# Current Category:-  women-belts
#
# Time Elapsed:-  0.35 mins
#
#
# Total Amount scraped :-   1855
# Current Category:-  women-belts
#
# Time Elapsed:-  0.37 mins
#
#
# Total Amount scraped :-   1933
# Current Category:-  women-ties
#
# Time Elapsed:-  0.4 mins
#
#
# Total Amount scraped :-   1938
# Current Category:-  women-pocket-squares
#
# Time Elapsed:-  0.41 mins
#
#
# Total Amount scraped :-   1942
# Current Category:-  women-caps
#
# Time Elapsed:-  0.43 mins
#
#
# Total Amount scraped :-   1944
# Current Category:-  women-hats
#
# Time Elapsed:-  0.45 mins
#
#
# Total Amount scraped :-   1962
# Current Category:-  women-scarves
#
# Time Elapsed:-  0.47 mins
#
#
# Total Amount scraped :-   1963
# Current Category:-  women-gloves
#
# Time Elapsed:-  0.49 mins
#
#
# Total Amount scraped :-   1964
# Current Category:-  women-phones-cases
#
# Time Elapsed:-  0.51 mins
#
#
# Total Amount scraped :-   2057
# Current Category:-  women-rings
#
# Time Elapsed:-  0.53 mins
#
#
# Total Amount scraped :-   2094
# Current Category:-  women-socks
#
# Time Elapsed:-  0.55 mins
#
#
# Total Amount scraped :-   2113
# Current Category:-  women-bracelets
#
# Time Elapsed:-  0.57 mins
#
#
# Total Amount scraped :-   2129
# Current Category:-  women-chains
#
# Time Elapsed:-  0.59 mins
#
#
#
# Total Time Elapsed:-  0.59 mins

# %%
df = pd.read_csv("bananarep.csv")
df = df.drop_duplicates()
df.dropna(inplace = True)
df["Affiliate_Link"] = [None]*df.shape[0]
df
# Out:
#                              Website  \
# 0     https://bananarepublic.gap.com
# 1     https://bananarepublic.gap.com
# 2     https://bananarepublic.gap.com
# 3     https://bananarepublic.gap.com
# 4     https://bananarepublic.gap.com
# ...                              ...
# 2886  https://bananarepublic.gap.com
# 2902  https://bananarepublic.gap.com
# 2992  https://bananarepublic.gap.com
# 3006  https://bananarepublic.gap.com
# 3014  https://bananarepublic.gap.com
#
#                                            Product_Link  \
# 0     https://bananarepublic.gap.com/browse/product....
# 1     https://bananarepublic.gap.com/browse/product....
# 2     https://bananarepublic.gap.com/browse/product....
# 3     https://bananarepublic.gap.com/browse/product....
# 4     https://bananarepublic.gap.com/browse/product....
# ...                                                 ...
# 2886  https://bananarepublic.gap.com/browse/product....
# 2902  https://bananarepublic.gap.com/browse/product....
# 2992  https://bananarepublic.gap.com/browse/product....
# 3006  https://bananarepublic.gap.com/browse/product....
# 3014  https://bananarepublic.gap.com/browse/product....
#
#                               Product_Name    Product_Brand Product_Category  \
# 0         Organic Soft Wash Henley T-Shirt  Banana Republic     men-clothing
# 1     Untucked Slim-Fit Linen-Cotton Shirt  Banana Republic     men-clothing
# 2                Organic Crew-Neck T-Shirt  Banana Republic     men-clothing
# 3         Authentic SUPIMA® T-Shirt Hoodie  Banana Republic     men-clothing
# 4                     Organic Shirt Jacket  Banana Republic     men-clothing
# ...                                    ...              ...              ...
# 2886               Stretch Leather Legging  Banana Republic     women-gloves
# 2902          Metallic Strappy Flat Sandal  Banana Republic      women-rings
# 2992           Textured Basic Trouser Sock  Banana Republic      women-socks
# 3006                  Textured Bootie Sock  Banana Republic      women-socks
# 3014             Control Top Opaque Tights  Banana Republic      women-socks
#
#                                              Size_Avail  Price    MRP Gender  \
# 0     Tops|size|Regular|XS|,Tops|size|Regular|XL|,To...   36.5   36.5    men
# 1     Tops|size|Regular|M|,Tops|size|Regular|XXL|,To...   69.5   69.5    men
# 2     Tops|size|Regular|XXL|,Tops|size|Tall|M|,Tops|...   34.5   34.5    men
# 3     Tops|size|Regular|XL|,Tops|size|Regular|XS|,To...   59.5   59.5    men
# 4     Tops|size|Regular|S|,Tops|size|Tall|XXL|,Tops|...   98.5   98.5    men
# ...                                                 ...    ...    ...    ...
# 2886  Bottoms|size|Regular|20|XXL,Bottoms|inseam|Reg...  598.0  598.0  women
# 2902  Shoes|size|Regular|7|,Shoes|size|Regular|9|,Sh...   88.0   88.0  women
# 2992              Socks & Tights|size|Regular|One Size|    6.0    6.0  women
# 3006              Socks & Tights|size|Regular|One Size|    5.0    5.0  women
# 3014  Socks & Tights|size|Regular|L|,Socks & Tights|...   11.0   11.0  women
#
#                                             Description  \
# 0     SOFT WASH: These shirts undergo a delicate was...
# 1     LINEN & COTTON: A match made in heaven  this s...
# 2                          Better cotton  better planet
# 3     SUPIMA® COTTON: Soft  strong  and American gro...
# 4     Specially washed for added softness  this vers...
# ...                                                 ...
# 2886  Stand apart in these exquisite leather legging...
# 2902                                          So summer
# 2992  Lightweight cotton blend socks with angled toe...
# 3006  Lightweight cotton blend socks with angled toe...
# 3014  A seasonal favorite  our control-top tights ha...
#
#                           Primary_Image_Links  \
# 0     /webcontent/0026/927/786/cn26927786.jpg
# 1     /webcontent/0026/929/387/cn26929387.jpg
# 2     /webcontent/0027/248/766/cn27248766.jpg
# 3     /webcontent/0026/937/790/cn26937790.jpg
# 4     /webcontent/0020/702/373/cn20702373.jpg
# ...                                       ...
# 2886  /webcontent/0027/347/012/cn27347012.jpg
# 2902  /webcontent/0018/852/752/cn18852752.jpg
# 2992  /webcontent/0013/910/160/cn13910160.jpg
# 3006  /webcontent/0013/910/140/cn13910140.jpg
# 3014  /webcontent/0016/595/955/cn16595955.jpg
#
#                                   Secondary_Image_Links Affiliate_Link
# 0     https://bananarepublic.gap.com/webcontent/0026...           None
# 1     https://bananarepublic.gap.com/webcontent/0026...           None
# 2     https://bananarepublic.gap.com/webcontent/0027...           None
# 3     https://bananarepublic.gap.com/webcontent/0027...           None
# 4     https://bananarepublic.gap.com/webcontent/0020...           None
# ...                                                 ...            ...
# 2886  https://bananarepublic.gap.com/webcontent/0027...           None
# 2902  https://bananarepublic.gap.com/webcontent/0018...           None
# 2992  https://bananarepublic.gap.com/webcontent/0013...           None
# 3006  https://bananarepublic.gap.com/webcontent/0013...           None
# 3014  https://bananarepublic.gap.com/webcontent/0016...           None
#
# [2200 rows x 13 columns]

# %%
conn = sqlite3.connect('BananaRepublic.db')
c = conn.cursor()
c.execute('CREATE TABLE product_details (Website varchar(40) NOT NULL, Product_Link TEXT PRIMARY KEY,Product_Name varchar(50) NOT NULL,Product_Brand varchar(50) NOT NULL,Product_Category varchar(50),Size_Avail varchar(20) NOT NULL,Price int NOT NULL,MRP int NOT NULL,Gender varchar(15) NOT NULL,Description TEXT NOT NULL,Primary_Image_Links TEXT NOT NULL,Secondary_Image_Links TEXT NOT NULL,Affiliate_Link TEXT NOT NULL)')
conn.commit()
df.to_sql('product_details', conn, if_exists='replace', index = False)

# %%
# Print 20 products
c.execute('''
SELECT * FROM product_details
          ''')

for row in c.fetchmany(size=20):
    print (row)
# Out:
# ('https://bananarepublic.gap.com', 'https://bananarepublic.gap.com/browse/product.do?pid