# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import warnings
warnings.filterwarnings("ignore")
import sqlite3
import requests
import json

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

# %%
conn=sqlite3.connect("LifeStyleStores.db")  
c=conn.cursor()

# %%
c.execute("""CREATE TABLE product_details
            (Website varchar(40) not null,
            Product_Link text PRIMARY KEY,
            Product_Name varchar(50) not null,
            Product_Brand varchar(50) not null,
            Product_Category varchar(50) not null,
            Size_Avail varchar(20) not null,
            Price int not null,
            MRP int not null,
            Gender varchar(15) not null,
            Description text not null,
            Primary_Image_Links text not null,
            Secondary_Image_Links text not null,
            Affiliate_Link text not null )""")

# %%
path="C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(path)

# %% [markdown]
# # Mens: Casual Shirts

# %%
product_link = {}
count = 0

for j in range(0,21):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-tops-casualshirts?p={j}')
    driver.implicitly_wait(5)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Formal Shirts

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,13):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-tops-formalshirts?p={j}')
    driver.implicitly_wait(5)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Jackets

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,4):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-tops-jackets?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(29,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(33,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Polos

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,21):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-tops-polos?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Hoodies and SweatShirts

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,7):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-winterwear-hoodiesandsweatshirts?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: T-shirts

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,21):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-tops-tshirts?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(29,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(33,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Casual-Trousers

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(7,15):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-bottoms-casualtrousers?p={j}')
    driver.implicitly_wait(2)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Formal-Trousers

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,5):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-bottoms-formaltrousers?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Jeans

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,14):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-bottoms-jeans?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Shorts & 3/4Ths

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,10):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-bottoms-shortsand34ths?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(25,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(29,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Track Pants

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,6):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-bottoms-trackpants?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Kurtas

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,3):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-ethnicwear-kurtas?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(27,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(31,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Shoes

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,14):

    driver.get(f'https://www.lifestylestores.com/in/en/c/shoesandbags-men?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(43,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(47,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Watches

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,5):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-watches?p={j}')
    driver.implicitly_wait(3)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(37,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(41,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Sunglasses

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,2):

    driver.get(f'https://www.lifestylestores.com/in/en/c/men-sunglasses?p={j}')
    driver.implicitly_wait(2)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(43,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(47,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)

# %% [markdown]
# # Mens: Accessories

# %%
options = webdriver.ChromeOptions()


driver = webdriver.Chrome()
product_link = {}
count = 0

for j in range(0,5):

    driver.get(f'https://www.lifestylestores.com/in/en/c/accessories-men?p={j}')
    driver.implicitly_wait(2)
    
    for i in range(1,49):
        time.sleep(0.1)
        
        if j == 0:
            try:      
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(37,i))
                no_button.click()
                
            except:
                continue
        else:
            try:              
                driver.implicitly_wait(2)
                no_button = driver.find_element_by_xpath("//div[@class ='MuiGrid-root jss2{} MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-3'][{}]".format(41,i))
                no_button.click()
            except:
                continue  
        try:
                time.sleep(0.1)
                product_lin = driver.find_element_by_id("product-details-description")
                product_link_ = product_lin.get_attribute('innerHTML')
                soup = BeautifulSoup(product_link_, 'lxml')
                product_link_data = soup.find('input', class_ = 'single-product-color-input').attrs['value']
                web = 'https://www.lifestylestores.com/'
                link = "https://www.lifestylestores.com/p/"+product_link_data
                name = driver.find_element_by_xpath("//h1[@id ='product-details-name']").text
                mrp = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[1].replace('Rs','').replace(',','')
                price = driver.find_element_by_xpath(".//div[@class ='product-price']").text.split()[2].replace('Rs','')
                prcat = 'Casual Shirts'    
                mask = driver.find_element_by_class_name("product-mask")
                mask_ = mask.get_attribute('innerHTML')
                soup = BeautifulSoup(mask_, 'lxml')
                image = []
                for i in soup.find_all('img'):
                    image.append(i.attrs['src'])
                priimg = image[0]
                secimg = image[1]

                info = driver.find_elements_by_xpath("//script[@type='application/ld+json']")
                for author in info: 
                    author_ = author.get_attribute('innerHTML')
                    soup1 = BeautifulSoup(author_, 'lxml')
                    jd = json.loads(soup1.text)
                    res = [jd[k]['name'] for k in ['brand'] if k in jd]
                    brand_name_lis = []
                    for brand_name_idx in res:
                        brand_name_lis.append(brand_name_idx)
                brand = ",".join(s for s in brand_name_lis)

                size = driver.find_element_by_id("filter-form-sizes")
                size_ = size.get_attribute('innerHTML')
                soup2 = BeautifulSoup(size_, 'lxml')
                sizes_ = []
                for ln in soup2.find_all('li'):
                    li = ln.find('label')
                    if "active" in li.attrs['class']:
                        sizes_.append(li.text.replace('\n', ''))
                sizes = ",".join(s for s in sizes_)

                description = driver.find_element_by_xpath(".//p[@id = 'product-details-p']").text
                gender = "Men"
                afl = ''
                c.execute('''INSERT INTO product_details VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (web, link, name, brand, prcat, sizes, price, mrp, gender, description, priimg, secimg, afl))
                conn.commit()
                
        except Exception as e:
            print(e)
            continue
        driver.back() 
        count+=1
      
    time.sleep(1)
